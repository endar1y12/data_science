# %% [markdown]
# [DATA](https://www.kaggle.com/datasets/rounakbanik/the-movies-dataset/data)
#
#
# Data yang digunakan adalah movies_metadata.csv.
#
# Format data yang sering digunakan untuk dianalisis yaitu excel,xml,json,csv.

# %%
#library
import pandas as pd #module untuk analisis data,editing df
import numpy as np # module yang digunakan untuk operasi matematika
import matplotlib.pyplot as plt # module yg digunakan untuk visualisasi data
import seaborn as sns # module untuk membuat visualisasi data
import os # untuk operasi matematika

# %%
#load data folder
os.chdir('/content/drive/MyDrive/data/movies')

# %%
#load data dalam folder
os.listdir()
# Out:
# ['links.csv',
#  'tested.csv',
#  'links_small.csv',
#  'keywords.csv',
#  'credits.csv',
#  'movies_metadata.csv',
#  'ratings_small.csv',
#  'ratings.csv']

# %%
#load data file csv
data = pd.read_csv('movies_metadata.csv')
data
# Out:
# <ipython-input-10-e895fe9acc36>:2: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('movies_metadata.csv')
#        adult                              belongs_to_collection    budget  \
# 0      False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      False                                                NaN  65000000
# 2      False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      False                                                NaN  16000000
# 4      False  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  False                                                NaN         0
# 45462  False                                                NaN         0
# 45463  False                                                NaN         0
# ...

# %%
#deskripsi data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
#.index -> menampilkan nama indeks .set_index -> membuat nama indeks berdasarkan kolom tertentu
#.reset.index() -> mereset dari index

data.head() # menampilkan 5 data,jika ingin lebih dari 5 maka -> data.head(10)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# ...

# %%
#menampilkan indeks data
data.index
# Out:
# RangeIndex(start=0, stop=45466, step=1)

# %%
# jika ingin menampilkan index sesuai judul data
datas = data.set_index('original_title')
datas
# Out:
#                              adult  \
# original_title
# Toy Story                    False
# Jumanji                      False
# Grumpier Old Men             False
# Waiting to Exhale            False
# Father of the Bride Part II  False
# ...                            ...
# رگ خواب                      False
# Siglo ng Pagluluwal          False
# Betrayal                     False
# Satana likuyushchiy          False
# Queerama                     False
#
#                                                          belongs_to_collection  \
# original_title
# Toy Story                    {'id': 10194, 'name': 'Toy Story Collection', ...
# Jumanji                                                                    NaN
# Grumpier Old Men             {'id': 119050, 'name': 'Grumpy Old Men Collect...
# Waiting to Exhale                                                          NaN
# Father of the Bride Part II  {'id': 96871, 'name': 'Father of the Bride Col...
# ...

# %%
datas.index
# Out:
# Index(['Toy Story', 'Jumanji', 'Grumpier Old Men', 'Waiting to Exhale',
#        'Father of the Bride Part II', 'Heat', 'Sabrina', 'Tom and Huck',
#        'Sudden Death', 'GoldenEye',
#        ...
#        'House of Horrors', 'Shadow of the Blair Witch', 'The Burkittsville 7',
#        'Caged Heat 3000', 'Robin Hood', 'رگ خواب', 'Siglo ng Pagluluwal',
#        'Betrayal', 'Satana likuyushchiy', 'Queerama'],
#       dtype='object', name='original_title', length=45466)

# %%
#kembalikan index data ke semula
new_data = data.reset_index()
new_data.index
# Out:
# RangeIndex(start=0, stop=45466, step=1)

# %%
#ambil data
new_data.loc[12]
# Out:
# index                                                                   12
# adult                                                                False
# belongs_to_collection    {'id': 117693, 'name': 'Balto Collection', 'po...
# budget                                                                   0
# genres                   [{'id': 10751, 'name': 'Family'}, {'id': 16, '...
# homepage                                                               NaN
# id                                                                   21032
# imdb_id                                                          tt0112453
# original_language                                                       en
# original_title                                                       Balto
# overview                 An outcast half-wolf risks his life to prevent...
# popularity                                                       12.140733
# ...

# %%
#ambil data berdasarkan kolom
new_data.loc[:,['original_title']]
# Out:
#                     original_title
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...                            ...
# 45461                      رگ خواب
# 45462          Siglo ng Pagluluwal
# 45463                     Betrayal
# 45464          Satana likuyushchiy
# 45465                     Queerama
#
# [45466 rows x 1 columns]

# %%
#menampilkan info kolom yang ada didata
new_data.columns
# Out:
# Index(['index', 'adult', 'belongs_to_collection', 'budget', 'genres',
#        'homepage', 'id', 'imdb_id', 'original_language', 'original_title',
#        'overview', 'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
#ambil data berdasarkan beberapa kolom
new_data.loc[:,['original_title','genres','vote_count','popularity']]
# Out:
#                     original_title  \
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...                            ...
# 45461                      رگ خواب
# 45462          Siglo ng Pagluluwal
# 45463                     Betrayal
# 45464          Satana likuyushchiy
# 45465                     Queerama
#
#                                                   genres  vote_count  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...      5415.0
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...      2413.0
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...        92.0
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...        34.0
# 4                         [{'id': 35, 'name': 'Comedy'}]       173.0
# ...                                                  ...         ...
# ...
